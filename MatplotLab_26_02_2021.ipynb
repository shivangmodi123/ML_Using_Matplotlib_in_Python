# %%
import matplotlib.pyplot as plt
import pandas as pd

# line Chart
x=[5,6,7,8,1]
y=[1,4,6,8,2]
x1=[2,4,6,8]
y1=[4,8,12,16]
plt.plot(x,y,'g',linewidth='3', linestyle='--', label="line1",marker="^")
plt.plot(x1,y1,'b',linewidth='5', linestyle='-', label="line2",marker="o")
#plt.xlable("X-Axis")
#plt.ylable("Y-Axis")
plt.title("Plot Chart")
plt.show()

# %%
https://www.kaggle.com/c/titanic/data
